# %%
import pandas as pd

df = pd.read_csv('Predictive_Maintenance_Dataset.csv')

# %%
power = []
for current in df['motor_current']:
    power.append(current * 220)

df['power'] = power

# %%
df = df[['timestamp', 'temperature', 'vibration', 'pressure', 'motor_current', 'power', 'failure']]

# %%
df
# Out:
#                 timestamp  temperature  vibration    pressure  motor_current  \
# 0     2025-01-01 00:00:00    77.483571   0.515248   93.215053       9.713154
# 1     2025-01-01 00:01:00    74.338684   0.509312   96.995015       9.944690
# 2     2025-01-01 00:02:00    78.298451   0.240851   94.126203      10.148592
# 3     2025-01-01 00:03:00    82.705154   0.533937  101.254188      11.923724
# 4     2025-01-01 00:04:00    73.949225   0.746486  112.171772       8.545563
# ...                   ...          ...        ...         ...            ...
# 4995  2025-01-04 11:15:00    73.852892   0.855590   89.399675      10.474894
# 4996  2025-01-04 11:16:00    77.683431   0.195997  110.915474      12.463526
# 4997  2025-01-04 11:17:00    89.719678   0.454889  111.713959      10.475084
# 4998  2025-01-04 11:18:00    78.224141   0.695382   89.798843      13.155046
# 4999  2025-01-04 11:19:00    69.972547   0.725374   97.150274       6.497786
#
#             power  failure
# ...

# %%
df.to_csv('Predictive_Maintenance_v2.csv', index=False)
